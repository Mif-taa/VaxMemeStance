# %%
import subprocess, sys

subprocess.run(["nvidia-smi"], check=False)
subprocess.run([
    sys.executable, "-m", "pip", "install",
    "transformers", "open-clip-torch", "--quiet"
], check=True)

print("✓ Packages ready")
# Out:
# Wed Mar  4 19:56:16 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   37C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 21.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.0 MB/s eta 0:00:00
# ✓ Packages ready

# %%
import os

WORK_DIR = "/kaggle/working"

BASE = "/kaggle/input/datasets/rishta19/vaccine-meme-dataset"

TRAIN_IMGDIR    = f"{BASE}/train-20260302T182945Z-3-001/train/train_images"
TRAIN_LABEL_CSV = f"{BASE}/train-20260302T182945Z-3-001/train/index_label_train.csv"
TRAIN_TEXT_CSV  = f"{BASE}/train-20260302T182945Z-3-001/train/train.csv"

EVAL_IMGDIR     = f"{BASE}/eval-20260302T182800Z-3-001/eval/val_no_labels/val_images"
EVAL_LABEL_CSV  = f"{BASE}/eval-20260302T182800Z-3-001/eval/index_label_val.csv"
EVAL_TEXT_CSV   = f"{BASE}/eval-20260302T182800Z-3-001/eval/val.csv"

TEST_IMGDIR     = f"{BASE}/test_release-20260302T183217Z-3-001/test_release/test_images"
TEST_TEXT_CSV   = f"{BASE}/test_release-20260302T183217Z-3-001/test_release/index_text.csv"

CSV_DIR = f"{WORK_DIR}/csvs"
os.makedirs(CSV_DIR, exist_ok=True)

checks = {
    "TRAIN_IMGDIR":    TRAIN_IMGDIR,
    "TRAIN_LABEL_CSV": TRAIN_LABEL_CSV,
    "TRAIN_TEXT_CSV":  TRAIN_TEXT_CSV,
    "EVAL_IMGDIR":     EVAL_IMGDIR,
    "EVAL_LABEL_CSV":  EVAL_LABEL_CSV,
    "EVAL_TEXT_CSV":   EVAL_TEXT_CSV,
    "TEST_IMGDIR":     TEST_IMGDIR,
    "TEST_TEXT_CSV":   TEST_TEXT_CSV,
}
all_ok = True
for name, path in checks.items():
    ok = os.path.exists(path)
    print(f"  {'✓' if ok else '✗ NOT FOUND'}  {name}: {path}")
    if not ok: all_ok = False

if all_ok:
    print(f"\n✓ All paths verified")
    print(f"  Train images : {len(os.listdir(TRAIN_IMGDIR))} files")
    print(f"  Eval  images : {len(os.listdir(EVAL_IMGDIR))} files")
    print(f"  Test  images : {len(os.listdir(TEST_IMGDIR))} files")
else:
    print("\n✗ Fix paths above")
# Out:
#   ✓  TRAIN_IMGDIR: /kaggle/input/datasets/rishta19/vaccine-meme-dataset/train-20260302T182945Z-3-001/train/train_images
#   ✓  TRAIN_LABEL_CSV: /kaggle/input/datasets/rishta19/vaccine-meme-dataset/train-20260302T182945Z-3-001/train/index_label_train.csv
#   ✓  TRAIN_TEXT_CSV: /kaggle/input/datasets/rishta19/vaccine-meme-dataset/train-20260302T182945Z-3-001/train/train.csv
#   ✓  EVAL_IMGDIR: /kaggle/input/datasets/rishta19/vaccine-meme-dataset/eval-20260302T182800Z-3-001/eval/val_no_labels/val_images
#   ✓  EVAL_LABEL_CSV: /kaggle/input/datasets/rishta19/vaccine-meme-dataset/eval-20260302T182800Z-3-001/eval/index_label_val.csv
#   ✓  EVAL_TEXT_CSV: /kaggle/input/datasets/rishta19/vaccine-meme-dataset/eval-20260302T182800Z-3-001/eval/val.csv
#   ✓  TEST_IMGDIR: /kaggle/input/datasets/rishta19/vaccine-meme-dataset/test_release-20260302T183217Z-3-001/test_release/test_images
#   ✓  TEST_TEXT_CSV: /kaggle/input/datasets/rishta19/vaccine-meme-dataset/test_release-20260302T183217Z-3-001/test_release/index_text.csv
#
# ✓ All paths verified
#   Train images : 8195 files
#   Eval  images : 1024 files
#   Test  images : 1025 files

# %%
import pandas as pd

train_label = pd.read_csv(TRAIN_LABEL_CSV)
train_text  = pd.read_csv(TRAIN_TEXT_CSV)
eval_label  = pd.read_csv(EVAL_LABEL_CSV)
eval_text   = pd.read_csv(EVAL_TEXT_CSV)
test_text   = pd.read_csv(TEST_TEXT_CSV)

print("=== TRAIN label CSV ===")
print(f"  Columns: {train_label.columns.tolist()}  Shape: {train_label.shape}")

print("\n=== TRAIN text CSV ===")
print(f"  Columns: {train_text.columns.tolist()}  Shape: {train_text.shape}")
print(train_text.head(2).to_string())

print("\n=== EVAL label CSV ===")
print(f"  Columns: {eval_label.columns.tolist()}  Shape: {eval_label.shape}")

print("\n=== EVAL text CSV ===")
print(f"  Columns: {eval_text.columns.tolist()}  Shape: {eval_text.shape}")
print(eval_text.head(2).to_string())

print("\n=== TEST text CSV ===")
print(f"  Columns: {test_text.columns.tolist()}  Shape: {test_text.shape}")
print(test_text.head(2).to_string())

print("\n✓ All CSVs loaded")
# Out:
# === TRAIN label CSV ===
#   Columns: ['index', 'label']  Shape: (8195, 2)
#
# === TRAIN text CSV ===
#   Columns: ['index', 'label', 'post_text', 'image_text']  Shape: (8195, 4)
#    index  label                                                                                                                                                                                           post_text image_text
# 0    692      2  Got my second shot, fully vaxxed, baby! It went so much faster, there were a lot fewer people in line today. Hubby gets his second and daughter gets her first on Tuesday. https://t.co/fyBVS8XvU0        NaN
# 1  10016      2                                                                                                                    With ???@RimaBrusi???  - All #vaxxed up and ready to go! https://t.co/tpkMXIRwxA        NaN
#
# === EVAL label CSV ===
#   Columns: ['index', 'label']  Shape: (1024, 2)
#
# === EVAL text CSV ===
#   Columns: ['index', 'label', 'post_text', 'image_text']  Shape: (1024, 4)
#    index  label                                                                                                                                                                                                                                                                                                                                       post_text                                                              image_text
# 0   6790      1  #SirTomMoore is 100 years old, a #national #hero and #treasure but he has now contracted #COVID19 and is in hospital #unvaccinated\n\n#StanleyJohnson is 80, allegedly the father of the #PrimeMinister and has had BOTH his #CovidVaccine #vaccinations before Xmas\n #Luck??????\n#Shameless https://t.co/P6mYBHKh0E https://t.co/moxUifXfqd                                                                     NaN
# 1   4528      1                                                                                                                                                                                                                                                            The minute my doctor tells me it is safe, I will get vaxxed. https://t.co/Ft6t3VT5K0  Fm not getting the vaccinebecause we dont knowwhats in it starter pack
#
# === TEST text CSV ===
#   Columns: ['index', 'post_text', 'image_text']  Shape: (1025, 3)
#        index                                                                                                                                                                                                                                                                                            post_text                                                                                                                                                                                                                                                                                                                                                            image_text
# 0  11786.png                                                                                                                                                                                                                         Fully vaxxed. Boutta go hug my friends for ten years https://t.co/M8nCGKNNA2                                                                                                                                                                                                                                                                                                                                                                   NaN
# 1   7668.png  @GreatClips screenshot of the latest mask mandate in Indiana. my son is 4, My vaxxed husband was mask-less and U kicked him out, although he was 6????? from the ?????stylists????? #wow #bidenshaircuts #Covid #BREAKING made my baby cry? Wtf #greatclipsucks #babyhaters https://t.co/avpj4QoGAS  IndianaStatewide order YesGov Eric Holcombs order requires Hoosiers age 8and up to mask themselves in all indoor publicsettings and outdoors when they cannot maintain 6feet of distance from others Initially issued in lateJuly the mandate has been extended multiple timesand currently runs through at least March 31Learn more Read Indianas latest mask order
#
# ✓ All CSVs loaded

# %%
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

import torch
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

TWEET_COL = "post_text"
OCR_COL   = "image_text"

LABEL_NAMES = ["Vaccine-Critical", "Neutral", "Pro-Vaccine"]
NUM_CLASSES = 3

train_df = train_label[["index", "label"]].copy()
train_df["label"] = train_df["label"].astype(int)

eval_df = eval_label[["index", "label"]].copy()
eval_df["label"] = eval_df["label"].astype(int)

print(f"Train: {len(train_df)} rows")
print(train_df["label"].value_counts().rename({0:"Vaccine-Critical",1:"Neutral",2:"Pro-Vaccine"}).to_string())
print(f"\nEval : {len(eval_df)} rows")
print(eval_df["label"].value_counts().rename({0:"Vaccine-Critical",1:"Neutral",2:"Pro-Vaccine"}).to_string())

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1, 2]),
    y=train_df["label"].values
)
import torch
cw_tensor = torch.tensor(class_weights, dtype=torch.float32).to(DEVICE)
print(f"Class weight tensor: {cw_tensor}")

print(f"\nClass weights (balanced): {np.round(class_weights, 4)}")
print("  (higher weight = model penalised more for missing that class)")
print("✓ Labels normalised")
# Out:
# Train: 8195 rows
# label
# Pro-Vaccine         3199
# Vaccine-Critical    2535
# Neutral             2461
#
# Eval : 1024 rows
# label
# Pro-Vaccine         389
# Neutral             327
# Vaccine-Critical    308
# Class weight tensor: tensor([1.0776, 1.1100, 0.8539], device='cuda:0')
#
# Class weights (balanced): [1.0776 1.11   0.8539]
#   (higher weight = model penalised more for missing that class)
# ✓ Labels normalised

# %%
LABEL_IMGDIR = f"{BASE}/train-20260302T182945Z-3-001/train/images_by_label"
if os.path.exists(LABEL_IMGDIR):
    for cls_folder in sorted(os.listdir(LABEL_IMGDIR)):
        cls_path = os.path.join(LABEL_IMGDIR, cls_folder)
        if os.path.isdir(cls_path):
            count = len(os.listdir(cls_path))
            print(f"  {cls_folder}: {count} images")
# Out:
#   anti_vaccine: 2535 images
#   neutral: 2461 images
#   pro_vaccine: 3199 images

# %%
def make_text_lookup(df, tweet_col, ocr_col=None):
    lookup = {}
    for _, r in df.iterrows():
        raw_idx = str(r["index"]).strip()
        idx = raw_idx if raw_idx.endswith(".png") else raw_idx + ".png"

        tweet = str(r.get(tweet_col, "") or "").strip()
        ocr   = str(r.get(ocr_col,   "") or "").strip() if ocr_col else ""
        tweet = "" if tweet.lower() == "nan" else tweet
        ocr   = "" if ocr.lower()   == "nan" else ocr

        if tweet and ocr:
            lookup[idx] = f"{tweet} [SEP] {ocr}"
        elif tweet:
            lookup[idx] = tweet
        elif ocr:
            lookup[idx] = ocr
        else:
            lookup[idx] = ""
    return lookup

train_text_lookup = make_text_lookup(train_text, TWEET_COL, OCR_COL)
eval_text_lookup  = make_text_lookup(eval_text,  TWEET_COL, OCR_COL)
test_text_lookup  = make_text_lookup(test_text,  TWEET_COL, OCR_COL)

for name, lookup in [("train", train_text_lookup),
                      ("eval",  eval_text_lookup),
                      ("test",  test_text_lookup)]:
    empty = sum(1 for v in lookup.values() if not v.strip())
    print(f"  {name}: {len(lookup)} entries  |  empty: {empty}")

print("\nSample train texts:")
for k, v in list(train_text_lookup.items())[:3]:
    print(f"  {k}: '{v[:100]}'")
print("✓ Text lookups ready")
# Out:
#   train: 8195 entries  |  empty: 0
#   eval: 1024 entries  |  empty: 0
#   test: 1025 entries  |  empty: 0
#
# Sample train texts:
#   692.png: 'Got my second shot, fully vaxxed, baby! It went so much faster, there were a lot fewer people in lin'
#   10016.png: 'With ???@RimaBrusi???  - All #vaxxed up and ready to go! https://t.co/tpkMXIRwxA'
#   3516.png: 'This beautiful frontline RN just got vaxxed! I?????m so happy ?????? @lynne_lisa #COVID19Vaccine #Va'
# ✓ Text lookups ready

# %%
def build_model_csv(label_df, img_dir, text_lookup, out_path, is_test=False):
    rows = []
    if is_test:
        for fname in sorted(f for f in os.listdir(img_dir)
                            if f.lower().endswith((".jpg",".jpeg",".png",".webp"))):
            rows.append({
                "index":      fname,
                "image_path": os.path.join(img_dir, fname),
                "text":       text_lookup.get(fname, ""),
            })
    else:
        for _, row in label_df.iterrows():
            idx = str(row["index"])
            rows.append({
                "index":      idx,
                "image_path": os.path.join(img_dir, idx),
                "text":       text_lookup.get(idx, ""),
                "label":      int(row["label"]),
            })
    df = pd.DataFrame(rows)
    df.to_csv(out_path, index=False)
    empty = (df["text"].fillna("").str.strip() == "").sum() if not is_test else "n/a"
    print(f"  {os.path.basename(out_path)}: {len(df)} rows  |  empty text: {empty}")
    return df

train_csv_path = f"{CSV_DIR}/train.csv"
val_csv_path   = f"{CSV_DIR}/val.csv"
test_csv_path  = f"{CSV_DIR}/test.csv"

print("Building model CSVs:")
build_model_csv(train_df, TRAIN_IMGDIR, train_text_lookup, train_csv_path)
build_model_csv(eval_df,  EVAL_IMGDIR,  eval_text_lookup,  val_csv_path)
build_model_csv(None,     TEST_IMGDIR,  test_text_lookup,  test_csv_path, is_test=True)

print("\nSample train row:")
s = pd.read_csv(train_csv_path).iloc[0]
print(f"  index: {s['index']}")
print(f"  label: {s['label']}")
print(f"  text : '{str(s['text'])[:120]}'")
print("✓ CSVs ready")
# Out:
# Building model CSVs:
#   train.csv: 8195 rows  |  empty text: 0
#   val.csv: 1024 rows  |  empty text: 0
#   test.csv: 1025 rows  |  empty text: n/a
#
# Sample train row:
#   index: 692.png
#   label: 2
#   text : 'Got my second shot, fully vaxxed, baby! It went so much faster, there were a lot fewer people in line today. Hubby gets '
# ✓ CSVs ready

# %%
import torch, torch.nn as nn, torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from transformers import AutoModel, AutoTokenizer
from sklearn.metrics import classification_report, f1_score, precision_recall_fscore_support
import numpy as np, warnings, time
warnings.filterwarnings("ignore")

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device : {DEVICE}")
print(f"GPU    : {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'none'}")
# Out:
# Device : cuda
# GPU    : Tesla T4

# %%
from PIL import Image
from torchvision import transforms
from transformers import FlavaProcessor

class FlavaDataset(Dataset):
    """FLAVA multimodal — image + text processed together."""
    def __init__(self, csv_path, processor, max_text_len=128, is_test=False):
        self.df           = pd.read_csv(csv_path)
        self.processor    = processor
        self.max_text_len = max_text_len
        self.is_test      = is_test
        self.augment = transforms.Compose([
            transforms.RandomHorizontalFlip(p=0.4),
            transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.2),
            transforms.RandomAffine(degrees=10, translate=(0.08, 0.08)),
        ]) if not is_test else None

    def __len__(self): return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        try:
            image = Image.open(str(row["image_path"])).convert("RGB")
            if self.augment: image = self.augment(image)
        except Exception:
            image = Image.new("RGB", (224, 224), (128, 128, 128))

        text = str(row.get("text", "") or "").strip()
        text = "[empty]" if not text or text.lower() == "nan" else text

        enc = self.processor(
            text=text,
            images=image,
            return_tensors="pt",
            padding="max_length",
            max_length=self.max_text_len,
            truncation=True,
            return_codebook_pixels=False,
            return_image_mask=False,
        )

        item = {
            "index":               str(row["index"]),
            "input_ids":           enc["input_ids"].squeeze(0),
            "attention_mask":      enc["attention_mask"].squeeze(0),
            "token_type_ids":      enc["token_type_ids"].squeeze(0),
            "pixel_values":        enc["pixel_values"].squeeze(0),
        }
        if not self.is_test:
            item["label"] = torch.tensor(int(row["label"]), dtype=torch.long)
        return item


class TextOnlyDataset(Dataset):
    """Text only — unchanged."""
    def __init__(self, csv_path, tokenizer, max_text_len=256, is_test=False):
        self.df           = pd.read_csv(csv_path)
        self.tokenizer    = tokenizer
        self.max_text_len = max_text_len
        self.is_test      = is_test

    def __len__(self): return len(self.df)

    def __getitem__(self, idx):
        row  = self.df.iloc[idx]
        text = str(row.get("text", "") or "").strip()
        text = "[empty]" if not text or text.lower() == "nan" else text
        enc  = self.tokenizer(
            text, max_length=self.max_text_len,
            padding="max_length", truncation=True, return_tensors="pt")
        item = {
            "index":          str(row["index"]),
            "input_ids":      enc["input_ids"].squeeze(0),
            "attention_mask": enc["attention_mask"].squeeze(0),
        }
        if not self.is_test:
            item["label"] = torch.tensor(int(row["label"]), dtype=torch.long)
        return item


class ImageOnlyDataset(Dataset):
    """Image only — uses FLAVA processor for image."""
    def __init__(self, csv_path, processor, is_test=False):
        self.df        = pd.read_csv(csv_path)
        self.processor = processor
        self.is_test   = is_test
        self.augment = transforms.Compose([
            transforms.RandomHorizontalFlip(p=0.4),
            transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.2),
        ]) if not is_test else None

    def __len__(self): return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        try:
            image = Image.open(str(row["image_path"])).convert("RGB")
            if self.augment: image = self.augment(image)
        except Exception:
            image = Image.new("RGB", (224, 224), (128, 128, 128))

        enc = self.processor(
            images=image, return_tensors="pt",
            return_codebook_pixels=False, return_image_mask=False)
        item = {
            "index":        str(row["index"]),
            "pixel_values": enc["pixel_values"].squeeze(0),
        }
        if not self.is_test:
            item["label"] = torch.tensor(int(row["label"]), dtype=torch.long)
        return item

print("✓ All 3 Dataset classes defined (FLAVA)")
# Out:
# ✓ All 3 Dataset classes defined (FLAVA)

# %%
from transformers import FlavaModel, AutoModel, AutoTokenizer

class TextOnlyModel(nn.Module):
    """RoBERTa-large text only — unchanged."""
    def __init__(self, model_name, num_classes=3, dropout=0.3, freeze=True):
        super().__init__()
        self.encoder = AutoModel.from_pretrained(model_name)
        if freeze:
            for p in self.encoder.parameters():
                p.requires_grad = False
        hidden = self.encoder.config.hidden_size
        self.classifier = nn.Sequential(
            nn.Linear(hidden, 512), nn.LayerNorm(512), nn.GELU(), nn.Dropout(dropout),
            nn.Linear(512, 256),    nn.GELU(), nn.Dropout(dropout * 0.7),
            nn.Linear(256, num_classes)
        )

    def unfreeze_top_layers(self, n=4):
        for layer in list(self.encoder.encoder.layer)[-n:]:
            for p in layer.parameters(): p.requires_grad = True

    def forward(self, input_ids, attention_mask):
        out = self.encoder(input_ids=input_ids, attention_mask=attention_mask)
        cls = out.last_hidden_state[:, 0, :].float()
        return self.classifier(cls)


class ImageOnlyModel(nn.Module):
    """FLAVA image encoder only."""
    def __init__(self, flava_name, num_classes=3, dropout=0.3, freeze=True):
        super().__init__()
        self.flava = FlavaModel.from_pretrained(flava_name)
        if freeze:
            for p in self.flava.parameters():
                p.requires_grad = False
        hidden = self.flava.config.image_config.hidden_size  # 768
        self.classifier = nn.Sequential(
            nn.Linear(hidden, 512), nn.LayerNorm(512), nn.GELU(), nn.Dropout(dropout),
            nn.Linear(512, 256), nn.GELU(), nn.Dropout(dropout * 0.7),
            nn.Linear(256, num_classes)
        )

    def unfreeze_top_layers(self, n=4):
        layers = list(self.flava.image_model.encoder.layer)
        for layer in layers[-n:]:
            for p in layer.parameters(): p.requires_grad = True
        print(f"  Trainable: {sum(p.numel() for p in self.parameters() if p.requires_grad):,}")

    def forward(self, pixel_values):
        out = self.flava.get_image_features(pixel_values=pixel_values)
        cls = out[:, 0, :].float()
        return self.classifier(cls)


class FlavaFusionModel(nn.Module):
    """FLAVA full multimodal fusion — uses joint multimodal encoder."""
    def __init__(self, flava_name, num_classes=3, dropout=0.3, freeze=True):
        super().__init__()
        self.flava = FlavaModel.from_pretrained(flava_name)
        if freeze:
            for p in self.flava.parameters():
                p.requires_grad = False

        # FLAVA multimodal hidden size = 768
        mm_hidden = self.flava.config.multimodal_config.hidden_size

        self.classifier = nn.Sequential(
            nn.Linear(mm_hidden, 512), nn.LayerNorm(512), nn.GELU(), nn.Dropout(dropout),
            nn.Linear(512, 256),       nn.GELU(), nn.Dropout(dropout * 0.7),
            nn.Linear(256, num_classes)
        )

    def unfreeze_top_layers(self, n=4, **kwargs):
        # Unfreeze top n layers of multimodal encoder
        layers = list(self.flava.multimodal_model.encoder.layer)
        for layer in layers[-n:]:
            for p in layer.parameters(): p.requires_grad = True
        print(f"  Trainable: {sum(p.numel() for p in self.parameters() if p.requires_grad):,}")

    def forward(self, pixel_values, input_ids, attention_mask, token_type_ids):
        out = self.flava(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
            pixel_values=pixel_values,
        )
        # Use multimodal CLS token
        mm_cls = out.multimodal_output.last_hidden_state[:, 0, :].float()
        return self.classifier(mm_cls)

print("✓ All 3 Model classes defined (FLAVA)")
# Out:
# ✓ All 3 Model classes defined (FLAVA)

# %%
from tqdm.auto import tqdm
from transformers import get_cosine_schedule_with_warmup
import time

class LabelSmoothingLoss(nn.Module):
    def __init__(self, classes=NUM_CLASSES, smoothing=0.1):
        super().__init__()
        self.smoothing, self.cls = smoothing, classes
    def forward(self, logits, targets):
        confidence = 1.0 - self.smoothing
        smooth_val = self.smoothing / (self.cls - 1)
        with torch.no_grad():
            st = torch.full_like(logits, smooth_val)
            st.scatter_(1, targets.unsqueeze(1), confidence)
        return -(st * F.log_softmax(logits, -1)).sum(-1).mean()

class WeightedLabelSmoothingLoss(nn.Module):
    def __init__(self, class_weights, classes=NUM_CLASSES, smoothing=0.1):
        super().__init__()
        self.smoothing = smoothing
        self.cls       = classes
        self.register_buffer("weights", class_weights)
    def forward(self, logits, targets):
        confidence = 1.0 - self.smoothing
        smooth_val = self.smoothing / (self.cls - 1)
        with torch.no_grad():
            st = torch.full_like(logits, smooth_val)
            st.scatter_(1, targets.unsqueeze(1), confidence)
        log_prob      = F.log_softmax(logits, -1)
        sample_loss   = -(st * log_prob).sum(-1)
        sample_weight = self.weights[targets]
        return (sample_loss * sample_weight).mean()

scalers = {
    "text":   torch.amp.GradScaler('cuda'),
    "image":  torch.amp.GradScaler('cuda'),
    "fusion": torch.amp.GradScaler('cuda'),
    "flava":  torch.amp.GradScaler('cuda'),
}

def train_one_epoch(model, loader, opt, sched, criterion, mode="flava"):
    model.train()
    scaler = scalers[mode]
    total_loss, all_preds, all_labels = 0.0, [], []
    for batch in tqdm(loader, desc="  Train", leave=False):
        labels = batch["label"].to(DEVICE)
        opt.zero_grad()

        with torch.amp.autocast('cuda'):
            if mode == "text":
                logits = model(batch["input_ids"].to(DEVICE),
                               batch["attention_mask"].to(DEVICE))
            elif mode == "image":
                logits = model(batch["pixel_values"].to(DEVICE))
            elif mode == "flava":
                logits = model(
                    pixel_values=batch["pixel_values"].to(DEVICE),
                    input_ids=batch["input_ids"].to(DEVICE),
                    attention_mask=batch["attention_mask"].to(DEVICE),
                    token_type_ids=batch["token_type_ids"].to(DEVICE),
                )
            else:  # old fusion mode
                logits = model(batch["pixel_values"].to(DEVICE),
                               batch["input_ids"].to(DEVICE),
                               batch["attention_mask"].to(DEVICE))
            loss = criterion(logits, labels)

        if torch.isnan(loss) or torch.isinf(loss):
            opt.zero_grad(); continue

        scaler.scale(loss).backward()
        scaler.unscale_(opt)
        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        scaler.step(opt); scaler.update()
        sched.step()

        total_loss += loss.item()
        all_preds.extend(logits.argmax(-1).cpu().tolist())
        all_labels.extend(labels.cpu().tolist())
    return total_loss/len(loader), f1_score(
        all_labels, all_preds, average="macro", zero_division=0)


@torch.no_grad()
def evaluate(model, loader, mode="flava"):
    model.eval()
    all_preds, all_labels = [], []
    for batch in tqdm(loader, desc="  Val  ", leave=False):
        with torch.amp.autocast('cuda'):
            if mode == "text":
                logits = model(batch["input_ids"].to(DEVICE),
                               batch["attention_mask"].to(DEVICE))
            elif mode == "image":
                logits = model(batch["pixel_values"].to(DEVICE))
            elif mode == "flava":
                logits = model(
                    pixel_values=batch["pixel_values"].to(DEVICE),
                    input_ids=batch["input_ids"].to(DEVICE),
                    attention_mask=batch["attention_mask"].to(DEVICE),
                    token_type_ids=batch["token_type_ids"].to(DEVICE),
                )
            else:
                logits = model(batch["pixel_values"].to(DEVICE),
                               batch["input_ids"].to(DEVICE),
                               batch["attention_mask"].to(DEVICE))
        all_preds.extend(logits.argmax(-1).cpu().tolist())
        all_labels.extend(batch["label"].tolist())
    macro_f1 = f1_score(all_labels, all_preds, average="macro", zero_division=0)
    report   = classification_report(
        all_labels, all_preds, target_names=LABEL_NAMES, zero_division=0)
    return macro_f1, report


def run_training(model, train_loader, val_loader, cfg, mode="flava", cw_tensor=None):
    criterion = (WeightedLabelSmoothingLoss(cw_tensor)
                 if cw_tensor is not None else LabelSmoothingLoss())

    if cfg.get("unfreeze_epoch", 999) == 0:
        enc_params, head_params = [], []
        for name, p in model.named_parameters():
            if not p.requires_grad: continue
            is_enc = any(k in name for k in ["flava", "encoder", "roberta", "clip"])
            (enc_params if is_enc else head_params).append(p)
        optimizer = torch.optim.AdamW([
            {"params": enc_params,  "lr": 2e-6},
            {"params": head_params, "lr": cfg["lr"]},
        ], weight_decay=cfg["weight_decay"])
    else:
        params    = filter(lambda p: p.requires_grad, model.parameters())
        optimizer = torch.optim.AdamW(params, lr=cfg["lr"],
                                      weight_decay=cfg["weight_decay"])

    steps     = len(train_loader) * cfg["epochs"]
    scheduler = get_cosine_schedule_with_warmup(optimizer, int(0.1*steps), steps)

    best_f1, history = 0.0, []
    print(f"\n{'Ep':>3}  {'Loss':>7}  {'TrainF1':>8}  {'ValF1':>7}  {'Best':>5}  {'Sec':>5}")
    print("─" * 46)

    for epoch in range(1, cfg["epochs"] + 1):
        t0 = time.time()

        if epoch == cfg.get("unfreeze_epoch", 999):
            print(f"\n  ── Epoch {epoch}: unfreezing ──")
            model.unfreeze_top_layers(4)

            enc_params, head_params = [], []
            for name, p in model.named_parameters():
                if not p.requires_grad: continue
                is_enc = any(k in name for k in ["flava", "encoder", "roberta"])
                (enc_params if is_enc else head_params).append(p)

            optimizer = torch.optim.AdamW([
                {"params": enc_params,  "lr": 2e-6},
                {"params": head_params, "lr": cfg["lr"]},
            ], weight_decay=cfg["weight_decay"])
            remaining = len(train_loader) * (cfg["epochs"] - epoch + 1)
            scheduler = get_cosine_schedule_with_warmup(
                optimizer, int(0.1*remaining), remaining)
            scalers[mode] = torch.amp.GradScaler('cuda')

        loss, tr_f1    = train_one_epoch(
            model, train_loader, optimizer, scheduler, criterion, mode)
        val_f1, report = evaluate(model, val_loader, mode)
        elapsed        = time.time() - t0
        is_best        = val_f1 > best_f1

        if is_best:
            best_f1 = val_f1
            torch.save(model.state_dict(), cfg["save_path"])

        history.append({"epoch":epoch,"loss":loss,"train_f1":tr_f1,"val_f1":val_f1})
        print(f"  {epoch:2d}   {loss:7.4f}   {tr_f1:8.4f}   {val_f1:7.4f}"
              f"   {'★' if is_best else ' '}    {elapsed:4.0f}s")
        if is_best: print(f"\n{report}\n")

    print(f"\n✓ Best Val Macro-F1: {best_f1:.4f} → {cfg['save_path']}")
    return best_f1, history

print("✓ Training functions defined (FLAVA-compatible)")
# Out:
# ✓ Training functions defined (FLAVA-compatible)

# %%
import pandas as pd

df = pd.read_csv(f"{WORK_DIR}/csvs/train.csv")
print(f"Columns: {df.columns.tolist()}")
print(f"Empty text: {(df['text'].fillna('').str.strip() == '').sum()} / {len(df)}")
print(f"\nFirst 5 rows:")
for _, r in df.head(5).iterrows():
    print(f"  label={r['label']}  text='{str(r['text'])[:100]}'")

print("\n--- Source train.csv ---")
src = pd.read_csv(TRAIN_TEXT_CSV)
print(f"Columns: {src.columns.tolist()}")
print(f"post_text empty: {src['post_text'].isna().sum()} / {len(src)}")
print(src[['index','post_text','image_text']].head(3).to_string())
# Out:
# Columns: ['index', 'image_path', 'text', 'label']
# Empty text: 0 / 8195
#
# First 5 rows:
#   label=2  text='Got my second shot, fully vaxxed, baby! It went so much faster, there were a lot fewer people in lin'
#   label=2  text='With ???@RimaBrusi???  - All #vaxxed up and ready to go! https://t.co/tpkMXIRwxA'
#   label=2  text='This beautiful frontline RN just got vaxxed! I?????m so happy ?????? @lynne_lisa #COVID19Vaccine #Va'
#   label=0  text='In Kenya, the catholic church unearthed an ongoing campaign by globalists to sterilize women of repr'
#   label=2  text='Excited to be vaxxed! #fauciouchie https://t.co/38dWULIuMV [SEP] covin19Cay ChoygtFac Nana Malar Tea'
#
# --- Source train.csv ---
# Columns: ['index', 'label', 'post_text', 'image_text']
# post_text empty: 0 / 8195
#    index                                                                                                                                                                                           post_text image_text
# 0    692  Got my second shot, fully vaxxed, baby! It went so much faster, there were a lot fewer people in line today. Hubby gets his second and daughter gets her first on Tuesday. https://t.co/fyBVS8XvU0        NaN
# 1  10016                                                                                                                    With ???@RimaBrusi???  - All #vaxxed up and ready to go! https://t.co/tpkMXIRwxA        NaN
# 2   3516                                                                This beautiful frontline RN just got vaxxed! I?????m so happy ?????? @lynne_lisa #COVID19Vaccine #Vaccinated https://t.co/ihXTCysC0m        NaN

# %%
TEXT_CFG = {
    "model_name":     "roberta-large",
    "max_text_len":   256,
    "batch_size":     8,
    "epochs":         8,
    "lr":             2e-5,
    "weight_decay":   1e-2,
    "unfreeze_epoch": 999,       
    "save_path":      f"{WORK_DIR}/best_text_model.pt",
}

print("=== EXPERIMENT 1: Text Only (RoBERTa-large) ===")
text_tok = AutoTokenizer.from_pretrained(TEXT_CFG["model_name"])

train_text_ds = TextOnlyDataset(train_csv_path, text_tok, TEXT_CFG["max_text_len"])
val_text_ds   = TextOnlyDataset(val_csv_path,   text_tok, TEXT_CFG["max_text_len"])

train_text_loader = DataLoader(
    train_text_ds, batch_size=TEXT_CFG["batch_size"],
    shuffle=True,  num_workers=0, pin_memory=True)
val_text_loader = DataLoader(
    val_text_ds,   batch_size=TEXT_CFG["batch_size"],
    shuffle=False, num_workers=0, pin_memory=True)

text_model = TextOnlyModel(
    TEXT_CFG["model_name"], dropout=0.4, freeze=False).to(DEVICE)

print(f"Total params    : {sum(p.numel() for p in text_model.parameters()):,}")
print(f"Trainable params: {sum(p.numel() for p in text_model.parameters() if p.requires_grad):,}")

text_f1, text_history = run_training(
    text_model, train_text_loader, val_text_loader,
    TEXT_CFG, mode="text", cw_tensor=cw_tensor)
# Out:
# === EXPERIMENT 1: Text Only (RoBERTa-large) ===
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# pooler.dense.bias               | MISSING    |
# pooler.dense.weight             | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Total params    : 356,017,667
# Trainable params: 356,017,667
#
#  Ep     Loss   TrainF1    ValF1   Best    Sec
# ──────────────────────────────────────────────
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    1    0.8469     0.6859    0.7924   ★     452s
#
#                   precision    recall  f1-score   support
#
# Vaccine-Critical       0.75      0.85      0.80       308
#          Neutral       0.73      0.71      0.72       327
#      Pro-Vaccine       0.89      0.83      0.86       389
#
#         accuracy                           0.80      1024
#        macro avg       0.79      0.79      0.79      1024
#     weighted avg       0.80      0.80      0.80      1024
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    2    0.7290     0.8064    0.8027   ★     453s
#
#                   precision    recall  f1-score   support
#
# Vaccine-Critical       0.76      0.87      0.81       308
#          Neutral       0.77      0.69      0.73       327
#      Pro-Vaccine       0.89      0.86      0.87       389
#
#         accuracy                           0.81      1024
#        macro avg       0.80      0.81      0.80      1024
#     weighted avg       0.81      0.81      0.81      1024
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    3    0.6785     0.8362    0.8038   ★     454s
#
#                   precision    recall  f1-score   support
#
# Vaccine-Critical       0.80      0.83      0.81       308
#          Neutral       0.70      0.78      0.74       327
#      Pro-Vaccine       0.92      0.81      0.86       389
#
#         accuracy                           0.80      1024
#        macro avg       0.81      0.81      0.80      1024
#     weighted avg       0.81      0.80      0.81      1024
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    4    0.6291     0.8715    0.8012         455s
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    5    0.5700     0.9095    0.7940         454s
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    6    0.5298     0.9330    0.7968         454s
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    7    0.5070     0.9461    0.7951         453s
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    8    0.4902     0.9537    0.7961         451s
#
# ✓ Best Val Macro-F1: 0.8038 → /kaggle/working/best_text_model.pt

# %%
FLAVA_NAME = "facebook/flava-full"

FLAVA_CFG = {
    "flava_name":     FLAVA_NAME,
    "max_text_len":   128,
    "batch_size":     8,
    "epochs":         10,
    "lr":             2e-5,
    "weight_decay":   1e-3,
    "unfreeze_epoch": 999,
    "save_path":      f"{WORK_DIR}/best_flava_model.pt",
}

print("=== EXPERIMENT 2: FLAVA Multimodal Fusion ===")
flava_processor = FlavaProcessor.from_pretrained(FLAVA_NAME)

train_flava_ds = FlavaDataset(train_csv_path, flava_processor, FLAVA_CFG["max_text_len"])
val_flava_ds   = FlavaDataset(val_csv_path,   flava_processor, FLAVA_CFG["max_text_len"])

train_flava_loader = DataLoader(train_flava_ds, batch_size=FLAVA_CFG["batch_size"],
                                 shuffle=True,  num_workers=0, pin_memory=True)
val_flava_loader   = DataLoader(val_flava_ds,   batch_size=FLAVA_CFG["batch_size"],
                                 shuffle=False, num_workers=0, pin_memory=True)

flava_model = FlavaFusionModel(
    FLAVA_NAME, num_classes=NUM_CLASSES,
    dropout=0.3, freeze=True).to(DEVICE)

print(f"Total params    : {sum(p.numel() for p in flava_model.parameters()):,}")
print(f"Trainable params: {sum(p.numel() for p in flava_model.parameters() if p.requires_grad):,}")

flava_f1, flava_history = run_training(
    flava_model, train_flava_loader, val_flava_loader,
    FLAVA_CFG, mode="flava", cw_tensor=cw_tensor)
# Out:
# === EXPERIMENT 2: FLAVA Multimodal Fusion ===
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# preprocessor_config.json:   0%|          | 0.00/881 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/358 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/512 [00:00<?, ?it/s]
# FlavaModel LOAD REPORT from: facebook/flava-full
# Key                                                                     | Status     |  |
# ------------------------------------------------------------------------+------------+--+-
# image_codebook.blocks.group_1.group.block_2.res_path.path.conv_3.weight | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_2.res_path.path.conv_4.weight | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_1.res_path.path.conv_1.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_2.res_path.path.conv_4.bias   | UNEXPECTED |  |
# mmm_text_head.transform.LayerNorm.bias                                  | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_1.res_path.path.conv_2.weight | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_2.res_path.path.conv_2.bias   | UNEXPECTED |  |
# mlm_head.decoder.bias                                                   | UNEXPECTED |  |
# mmm_text_head.transform.LayerNorm.weight                                | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_1.res_path.path.conv_2.bias   | UNEXPECTED |  |
# mlm_head.bias                                                           | UNEXPECTED |  |
# mmm_text_head.decoder.bias                                              | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_2.res_path.path.conv_4.weight | UNEXPECTED |  |
# mlm_head.transform.dense.weight                                         | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_2.res_path.path.conv_2.weight | UNEXPECTED |  |
# mim_head.transform.dense.bias                                           | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_2.res_path.path.conv_2.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_1.id_path.weight              | UNEXPECTED |  |
# mmm_image_head.decoder.bias                                             | UNEXPECTED |  |
# image_codebook.blocks.input.weight                                      | UNEXPECTED |  |
# itm_head.seq_relationship.weight                                        | UNEXPECTED |  |
# mmm_text_head.decoder.weight                                            | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_2.res_path.path.conv_2.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_2.res_path.path.conv_2.weight | UNEXPECTED |  |
# mmm_image_head.transform.LayerNorm.weight                               | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_1.res_path.path.conv_2.weight | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_1.res_path.path.conv_1.weight | UNEXPECTED |  |
# mim_head.transform.LayerNorm.bias                                       | UNEXPECTED |  |
# mmm_image_head.decoder.weight                                           | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_2.res_path.path.conv_1.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_2.res_path.path.conv_3.weight | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_1.id_path.bias                | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_1.res_path.path.conv_4.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_2.res_path.path.conv_4.weight | UNEXPECTED |  |
# mim_head.transform.LayerNorm.weight                                     | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_1.res_path.path.conv_3.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_1.res_path.path.conv_1.weight | UNEXPECTED |  |
# flava.text_model.embeddings.position_ids                                | UNEXPECTED |  |
# mmm_image_head.bias                                                     | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_1.res_path.path.conv_2.weight | UNEXPECTED |  |
# mlm_head.transform.dense.bias                                           | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_1.res_path.path.conv_2.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_2.res_path.path.conv_2.weight | UNEXPECTED |  |
# mmm_text_head.bias                                                      | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_1.res_path.path.conv_4.weight | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_1.res_path.path.conv_3.bias   | UNEXPECTED |  |
# mmm_image_head.transform.dense.weight                                   | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_2.res_path.path.conv_3.bias   | UNEXPECTED |  |
# itm_head.seq_relationship.bias                                          | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_1.res_path.path.conv_3.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_1.id_path.weight              | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_1.res_path.path.conv_2.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_1.res_path.path.conv_3.weight | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_2.res_path.path.conv_2.bias   | UNEXPECTED |  |
# itm_head.pooler.dense.bias                                              | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_2.res_path.path.conv_1.bias   | UNEXPECTED |  |
# mim_head.bias                                                           | UNEXPECTED |  |
# mim_head.decoder.weight                                                 | UNEXPECTED |  |
# mmm_image_head.transform.dense.bias                                     | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_1.id_path.bias                | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_1.res_path.path.conv_4.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_2.res_path.path.conv_1.weight | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_1.res_path.path.conv_4.weight | UNEXPECTED |  |
# mlm_head.decoder.weight                                                 | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_2.res_path.path.conv_1.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_1.res_path.path.conv_4.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_1.id_path.weight              | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_2.res_path.path.conv_4.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_2.res_path.path.conv_1.weight | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_1.res_path.path.conv_4.weight | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_2.res_path.path.conv_4.weight | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_1.res_path.path.conv_3.weight | UNEXPECTED |  |
# image_codebook.blocks.input.bias                                        | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_1.res_path.path.conv_4.weight | UNEXPECTED |  |
# image_codebook.blocks.output.conv.bias                                  | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_1.res_path.path.conv_1.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_1.res_path.path.conv_1.weight | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_1.res_path.path.conv_4.bias   | UNEXPECTED |  |
# mmm_text_head.transform.dense.weight                                    | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_1.res_path.path.conv_2.weight | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_2.res_path.path.conv_1.weight | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_2.res_path.path.conv_3.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_1.res_path.path.conv_3.weight | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_1.res_path.path.conv_2.bias   | UNEXPECTED |  |
# mim_head.decoder.bias                                                   | UNEXPECTED |  |
# mlm_head.transform.LayerNorm.weight                                     | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_2.res_path.path.conv_3.weight | UNEXPECTED |  |
# mlm_head.transform.LayerNorm.bias                                       | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_2.res_path.path.conv_3.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_1.id_path.bias                | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_2.res_path.path.conv_3.weight | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_1.res_path.path.conv_3.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_2.res_path.path.conv_1.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_2.res_path.path.conv_1.weight | UNEXPECTED |  |
# image_codebook.blocks.output.conv.weight                                | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_2.res_path.path.conv_2.weight | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_1.res_path.path.conv_1.bias   | UNEXPECTED |  |
# itm_head.pooler.dense.weight                                            | UNEXPECTED |  |
# image_codebook.blocks.group_3.group.block_2.res_path.path.conv_3.bias   | UNEXPECTED |  |
# mim_head.transform.dense.weight                                         | UNEXPECTED |  |
# image_codebook.blocks.group_4.group.block_2.res_path.path.conv_4.bias   | UNEXPECTED |  |
# mmm_image_head.transform.LayerNorm.bias                                 | UNEXPECTED |  |
# mmm_text_head.transform.dense.bias                                      | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_1.res_path.path.conv_3.weight | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_2.res_path.path.conv_4.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_2.group.block_1.res_path.path.conv_1.bias   | UNEXPECTED |  |
# image_codebook.blocks.group_1.group.block_1.res_path.path.conv_1.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# Total params    : 241,883,140
# Trainable params: 526,851
#
#  Ep     Loss   TrainF1    ValF1   Best    Sec
# ──────────────────────────────────────────────
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    1    1.0083     0.5205    0.6563   ★     597s
#
#                   precision    recall  f1-score   support
#
# Vaccine-Critical       0.71      0.54      0.61       308
#          Neutral       0.55      0.68      0.61       327
#      Pro-Vaccine       0.76      0.74      0.75       389
#
#         accuracy                           0.66      1024
#        macro avg       0.67      0.65      0.66      1024
#     weighted avg       0.68      0.66      0.66      1024
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    2    0.8467     0.6893    0.7332   ★     530s
#
#                   precision    recall  f1-score   support
#
# Vaccine-Critical       0.71      0.75      0.73       308
#          Neutral       0.67      0.66      0.66       327
#      Pro-Vaccine       0.83      0.79      0.81       389
#
#         accuracy                           0.74      1024
#        macro avg       0.73      0.73      0.73      1024
#     weighted avg       0.74      0.74      0.74      1024
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    3    0.8037     0.7250    0.7385   ★     538s
#
#                   precision    recall  f1-score   support
#
# Vaccine-Critical       0.70      0.80      0.75       308
#          Neutral       0.68      0.61      0.64       327
#      Pro-Vaccine       0.84      0.82      0.83       389
#
#         accuracy                           0.75      1024
#        macro avg       0.74      0.74      0.74      1024
#     weighted avg       0.75      0.75      0.74      1024
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    4    0.7845     0.7383    0.7478   ★     540s
#
#                   precision    recall  f1-score   support
#
# Vaccine-Critical       0.70      0.81      0.75       308
#          Neutral       0.69      0.65      0.67       327
#      Pro-Vaccine       0.86      0.79      0.83       389
#
#         accuracy                           0.75      1024
#        macro avg       0.75      0.75      0.75      1024
#     weighted avg       0.76      0.75      0.75      1024
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    5    0.7719     0.7479    0.7553   ★     540s
#
#                   precision    recall  f1-score   support
#
# Vaccine-Critical       0.76      0.74      0.75       308
#          Neutral       0.65      0.72      0.68       327
#      Pro-Vaccine       0.87      0.80      0.83       389
#
#         accuracy                           0.76      1024
#        macro avg       0.76      0.75      0.76      1024
#     weighted avg       0.76      0.76      0.76      1024
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    6    0.7592     0.7589    0.7572   ★     524s
#
#                   precision    recall  f1-score   support
#
# Vaccine-Critical       0.71      0.81      0.76       308
#          Neutral       0.70      0.66      0.68       327
#      Pro-Vaccine       0.86      0.81      0.83       389
#
#         accuracy                           0.76      1024
#        macro avg       0.76      0.76      0.76      1024
#     weighted avg       0.76      0.76      0.76      1024
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    7    0.7552     0.7608    0.7685   ★     522s
#
#                   precision    recall  f1-score   support
#
# Vaccine-Critical       0.73      0.84      0.78       308
#          Neutral       0.71      0.67      0.69       327
#      Pro-Vaccine       0.87      0.81      0.84       389
#
#         accuracy                           0.77      1024
#        macro avg       0.77      0.77      0.77      1024
#     weighted avg       0.78      0.77      0.77      1024
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    8    0.7498     0.7636    0.7691   ★     523s
#
#                   precision    recall  f1-score   support
#
# Vaccine-Critical       0.74      0.81      0.77       308
#          Neutral       0.70      0.69      0.70       327
#      Pro-Vaccine       0.87      0.81      0.84       389
#
#         accuracy                           0.77      1024
#        macro avg       0.77      0.77      0.77      1024
#     weighted avg       0.78      0.77      0.77      1024
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#    9    0.7436     0.7702    0.7594         526s
#   Train:   0%|          | 0/1025 [00:00<?, ?it/s]
#   Val  :   0%|          | 0/128 [00:00<?, ?it/s]
#   10    0.7423     0.7674    0.7578         511s
#
# ✓ Best Val Macro-F1: 0.7691 → /kaggle/working/best_flava_model.pt

# %%
# FUSION_CFG = {
#     "clip_name":       BIOMEDCLIP_NAME,
#     "text_name":       "roberta-large",
#     "fusion_dim":      512,
#     "num_attn_layers": 2,
#     "dropout":         0.3,
#     "max_text_len":    256,
#     "batch_size":      8,
#     "epochs":          10,
#     "lr":              2e-5,
#     "weight_decay":    1e-3,
#     "unfreeze_epoch":  999,
#     "save_path":       f"{WORK_DIR}/best_fusion_model.pt",
# }

# print("=== EXPERIMENT 3: Multimodal Fusion (BiomedCLIP + RoBERTa-large) ===")
# fusion_tok = AutoTokenizer.from_pretrained(FUSION_CFG["text_name"])

# train_fusion_ds = VaxMemeDataset(train_csv_path, fusion_tok, FUSION_CFG["max_text_len"])
# val_fusion_ds   = VaxMemeDataset(val_csv_path,   fusion_tok, FUSION_CFG["max_text_len"])

# train_fusion_loader = DataLoader(train_fusion_ds, batch_size=FUSION_CFG["batch_size"],
#                                   shuffle=True,  num_workers=0, pin_memory=True)
# val_fusion_loader   = DataLoader(val_fusion_ds,   batch_size=FUSION_CFG["batch_size"],
#                                   shuffle=False, num_workers=0, pin_memory=True)

# fusion_model = VaxMemeFusionModel(
#     clip_name=FUSION_CFG["clip_name"],
#     text_name=FUSION_CFG["text_name"],
#     fusion_dim=FUSION_CFG["fusion_dim"],
#     num_attn_layers=FUSION_CFG["num_attn_layers"],
#     dropout=FUSION_CFG["dropout"],
#     freeze_encoders=True,
# ).to(DEVICE)

# print(f"Total params    : {sum(p.numel() for p in fusion_model.parameters()):,}")
# print(f"Trainable params: {sum(p.numel() for p in fusion_model.parameters() if p.requires_grad):,}")

# fusion_f1, fusion_history = run_training(
#     fusion_model, train_fusion_loader, val_fusion_loader,
#     FUSION_CFG, mode="fusion", cw_tensor=cw_tensor)

# %%
@torch.no_grad()
def get_softmax_probs(model, loader, mode="flava"):
    model.eval()
    all_probs, all_labels, all_indices = [], [], []
    for batch in tqdm(loader, desc=f"  Probs/{mode}", leave=False):
        with torch.amp.autocast('cuda'):
            if mode == "text":
                logits = model(batch["input_ids"].to(DEVICE),
                               batch["attention_mask"].to(DEVICE))
            elif mode == "image":
                logits = model(batch["pixel_values"].to(DEVICE))
            elif mode == "flava":
                logits = model(
                    pixel_values=batch["pixel_values"].to(DEVICE),
                    input_ids=batch["input_ids"].to(DEVICE),
                    attention_mask=batch["attention_mask"].to(DEVICE),
                    token_type_ids=batch["token_type_ids"].to(DEVICE),
                )
            else:
                logits = model(batch["pixel_values"].to(DEVICE),
                               batch["input_ids"].to(DEVICE),
                               batch["attention_mask"].to(DEVICE))
        probs = torch.softmax(logits, dim=-1).cpu().numpy()
        all_probs.append(probs)
        if "label" in batch:
            all_labels.extend(batch["label"].tolist())
        if "index" in batch:
            all_indices.extend(batch["index"])
    return np.concatenate(all_probs, axis=0), all_labels, all_indices

print("✓ get_softmax_probs defined (FLAVA-compatible)")
# Out:
# ✓ get_softmax_probs defined (FLAVA-compatible)

# %%
import numpy as np
from sklearn.metrics import f1_score, precision_recall_fscore_support, classification_report
from itertools import product as iproduct

text_model.load_state_dict(torch.load(TEXT_CFG["save_path"],   map_location=DEVICE))
flava_model.load_state_dict(torch.load(FLAVA_CFG["save_path"], map_location=DEVICE))

print("Computing softmax probabilities...")
probs_text,  true_labels, _ = get_softmax_probs(text_model,  val_text_loader,  "text")
probs_flava, _,           _ = get_softmax_probs(flava_model, val_flava_loader, "flava")

true_labels = np.array(true_labels)
f1_txt = f1_score(true_labels, probs_text.argmax(1),  average="macro", zero_division=0)
f1_flv = f1_score(true_labels, probs_flava.argmax(1), average="macro", zero_division=0)

p1, r1, _, _ = precision_recall_fscore_support(true_labels, probs_text.argmax(1),  average="macro", zero_division=0)
p3, r3, _, _ = precision_recall_fscore_support(true_labels, probs_flava.argmax(1), average="macro", zero_division=0)

print("\n" + "="*62)
print(f"{'Model':<20} {'Classifier':<22} {'P':>6} {'R':>6} {'F1':>6}")
print("="*62)
print(f"{'Unimodal (Text)':<20} {'RoBERTa-large':<22} {p1:>6.4f} {r1:>6.4f} {f1_txt:>6.4f}")
print(f"{'Multimodal':<20} {'FLAVA-full':<22} {p3:>6.4f} {r3:>6.4f} {f1_flv:>6.4f}")
print("="*62)

total = f1_txt + f1_flv
w_t   = f1_txt / total
w_f   = f1_flv / total
print(f"\nEnsemble weights → text:{w_t:.3f}  flava:{w_f:.3f}")

ensemble_probs = w_t * probs_text + w_f * probs_flava
ensemble_preds = ensemble_probs.argmax(1)
f1_ens = f1_score(true_labels, ensemble_preds, average="macro", zero_division=0)
print(f"\n{'='*62}")
print(f"Weighted Ensemble Macro-F1: {f1_ens:.4f}")
print("="*62)
print(classification_report(true_labels, ensemble_preds,
                             target_names=LABEL_NAMES, zero_division=0))

def apply_thresholds(probs, thresholds):
    return (probs / np.array(thresholds)).argmax(1)

best_thresh_f1  = f1_ens
best_thresholds = [1.0, 1.0, 1.0]
threshold_vals  = [0.7, 0.8, 0.9, 1.0, 1.1, 1.2, 1.3]

print("\nSearching best per-class thresholds...")
for t0, t1, t2 in iproduct(threshold_vals, threshold_vals, threshold_vals):
    preds = apply_thresholds(ensemble_probs, [t0, t1, t2])
    f1    = f1_score(true_labels, preds, average="macro", zero_division=0)
    if f1 > best_thresh_f1:
        best_thresh_f1  = f1
        best_thresholds = [t0, t1, t2]

print(f"Best thresholds : {best_thresholds}")
print(f"Threshold-tuned Ensemble F1: {best_thresh_f1:.4f}  (raw: {f1_ens:.4f})")
print(classification_report(
    true_labels, apply_thresholds(ensemble_probs, best_thresholds),
    target_names=LABEL_NAMES, zero_division=0))
# Out:
# Computing softmax probabilities...
#   Probs/text:   0%|          | 0/128 [00:00<?, ?it/s]
#   Probs/flava:   0%|          | 0/128 [00:00<?, ?it/s]
# ==============================================================
# Model                Classifier                  P      R     F1
# ==============================================================
# Unimodal (Text)      RoBERTa-large          0.8067 0.8050 0.8038
# Multimodal           FLAVA-full             0.7657 0.7666 0.7653
# ==============================================================
#
# Ensemble weights → text:0.512  flava:0.488
#
# ==============================================================
# Weighted Ensemble Macro-F1: 0.8103
# ==============================================================
#                   precision    recall  f1-score   support
#
# Vaccine-Critical       0.81      0.85      0.83       308
#          Neutral       0.72      0.77      0.75       327
#      Pro-Vaccine       0.90      0.82      0.86       389
#
#         accuracy                           0.81      1024
#        macro avg       0.81      0.81      0.81      1024
#     weighted avg       0.82      0.81      0.81      1024
#
#
# Searching best per-class thresholds...
# Best thresholds : [0.7, 0.8, 1.1]
# Threshold-tuned Ensemble F1: 0.8183  (raw: 0.8103)
#                   precision    recall  f1-score   support
#
# Vaccine-Critical       0.80      0.88      0.83       308
#          Neutral       0.74      0.78      0.76       327
#      Pro-Vaccine       0.93      0.81      0.86       389
#
#         accuracy                           0.82      1024
#        macro avg       0.82      0.82      0.82      1024
#     weighted avg       0.83      0.82      0.82      1024

# %%
import zipfile

test_text_ds  = TextOnlyDataset(test_csv_path, text_tok,
                                 TEXT_CFG["max_text_len"], is_test=True)
test_flava_ds = FlavaDataset(test_csv_path, flava_processor,
                              FLAVA_CFG["max_text_len"], is_test=True)

test_text_loader  = DataLoader(test_text_ds,  batch_size=32, shuffle=False, num_workers=0)
test_flava_loader = DataLoader(test_flava_ds, batch_size=8,  shuffle=False, num_workers=0)

print("Running test inference...")
test_probs_text,  _, test_indices = get_softmax_probs(text_model,  test_text_loader,  "text")
test_probs_flava, _, _            = get_softmax_probs(flava_model, test_flava_loader, "flava")

test_ensemble = w_t * test_probs_text + w_f * test_probs_flava
test_preds    = apply_thresholds(test_ensemble, best_thresholds)

pred_df = pd.DataFrame({"index": test_indices, "label": test_preds})
pred_df["_key"] = pred_df["index"].str.extract(r"(\d+)").astype(int)
pred_df = pred_df.sort_values("_key").drop(columns="_key").reset_index(drop=True)

CSV_PATH = f"{WORK_DIR}/predictions.csv"
ZIP_PATH = f"{WORK_DIR}/submission.zip"
pred_df.to_csv(CSV_PATH, index=False)

df  = pd.read_csv(CSV_PATH)
ok  = (set(df.columns) == {"index","label"} and
       not df.isnull().any().any() and
       df["label"].isin({0,1,2}).all() and
       not df["index"].duplicated().any() and
       df["index"].str.extract(r"(\d+)")[0].astype(int).is_monotonic_increasing)

if ok:
    with zipfile.ZipFile(ZIP_PATH, "w", compression=zipfile.ZIP_DEFLATED) as zf:
        zf.write(CSV_PATH, arcname="predictions.csv")
    print(f"✓ submission.zip ready ({os.path.getsize(ZIP_PATH)/1024:.1f} KB)")
    print(f"  Best Val Ensemble F1: {best_thresh_f1:.4f}")
    print("→ Download from Kaggle Output tab → upload to Codabench")
else:
    print("✗ Validation failed — check predictions")
# Out:
# Running test inference...
#   Probs/text:   0%|          | 0/33 [00:00<?, ?it/s]
#   Probs/flava:   0%|          | 0/129 [00:00<?, ?it/s]
# ✓ submission.zip ready (2.9 KB)
#   Best Val Ensemble F1: 0.8183
# → Download from Kaggle Output tab → upload to Codabench
